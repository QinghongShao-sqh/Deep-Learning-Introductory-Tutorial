# %% [markdown]
# #Text to Image Generation with Neural Networks 2 - 詩句作畫<BR>
# This notebook shows how to use stable diffusion model to generate image from text with Chinese poems.

# %% [markdown]
# ##Install and Load Packages

# %%
# !pip install diffusers
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for diffusers: filename=diffusers-0.19.0-py3-none-any.whl size=1318234 sha256=8719516e87b86c4fdc1b77f6445dfc60372e2d3ae65fd55f4d23fd5b2dadf38f
#   Stored in directory: c:\users\10305\appdata\local\pip\cache\wheels\56\cc\2f\9732a06302e1d49f63981d794560302e089734769b808fd1ea
# Successfully built diffusers
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution - (f:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (f:\anaconda\lib\site-packages)
# ...

# %%
# !pip install setuptools-rust
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# cvxpy 1.2.3 requires setuptools<=64.0.2, but you have setuptools 65.7.0 which is incompatible.
# ...

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 76.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 58.5 MB/s eta 0:00:00
# ...

# %%
from diffusers import StableDiffusionPipeline

# %% [markdown]
# ##Load Model

# %%
#setup pipeline to pretrained model
pipe = StableDiffusionPipeline.from_pretrained("IDEA-CCNL/Taiyi-Stable-Diffusion-1B-Chinese-v0.1").to("cuda")
# Out:
# Downloading:   0%|          | 0.00/539 [00:00<?, ?B/s]
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/342 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.67k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/258 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/884 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/409M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/555 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/110k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/793 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/335M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ##Generate Image from Text

# %%
prompt = '遠上寒山石徑斜，白雲深處有人家。'
image = pipe(prompt, guidance_scale=7.5).images[0]  
image.save("白雲深處.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE616D70D30>

# %%
prompt = '罨畫清溪上, 蓑笠扁舟一隻, 油畫'
image = pipe(prompt, guidance_scale=7.5).images[0]  
image.save("罨畫清溪上.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE719D50D30>

# %% [markdown]
# ##Exercise <BR>
# 1. Try to generate an image with the Chinese poem with ink style: <BR>
# 床前明月光，疑是地上霜。舉頭望明月，低頭思故鄉。水墨畫<BR>
# Bright moonlight before my bed;<BR>
# I suppose it is frost on the ground.<BR>
# I raise my head to view the bright moon,<BR>
# then lower it, thinking of my home village.<BR>
# 2. Try to generate an image with the Chinese poem with science fiction style: <BR>
# 銀燭秋光冷畫屏，輕羅小扇撲流螢。天階夜色涼如水，臥看牽牛織女星。科幻, 桌面高清壁纸<BR>
# A candle flame flickers against a dull painted screen on an cool autumn night,<BR>
# She holds a small silk fan to flap away dashing fireflies.<BR>
# Above her hang celestial bodies as frigid as deep water,<BR>
# She sat there watching Altair of Aquila and Vega of Lyra pining for each other in the sky.<BR>

# %%
prompt = '床前明月光，疑是地上霜。舉頭望明月，低頭思故鄉。唯美，插画。'
image = pipe(prompt, guidance_scale=7.5).images[0]  
image.save("床前明月光.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE71ADCB8B0>

# %%
prompt = '銀燭秋光冷畫屏，輕羅小扇撲流螢。天階夜色涼如水，臥看牽牛織女星。科幻, 桌面高清壁纸'
image = pipe(prompt, guidance_scale=7.5).images[0]  
image.save("秋夕.png")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FE61548FF70>
